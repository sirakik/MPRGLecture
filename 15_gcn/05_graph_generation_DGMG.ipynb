# %% [markdown]
# # グラフ生成
#
# ---

# %% [markdown]
# グラフ生成とは,その名の通りグラフを生成する分野です.
# 最も一般的なタスクは, 化合物の生成です.
# 化合物の性質（水溶性,毒性...）を考慮しながら生成することで, 創薬研究などに役立ちます.
#
# 分子構造を考慮できるGCNの発展に伴い,グラフ生成分野も研究が進みました.
# グラフ生成にも色々なアプローチがありますが,ここではDGMGという手法について紹介します.
# 画像生成では出来ない,グラフ特有の生成の仕方なので面白いと思います.

# %% [markdown]
# #Deep Generative Models of Graphs (DGMG) [[arXiv](https://arxiv.org/pdf/1803.03324.pdf)]
#
# ---

# %% [markdown]
# DGMGは3つの識別器と,生成フローを組み合わせることでグラフを生成する手法です.
#
# 3つの識別器
# - add node：新しいノードを追加　or 追加しない (生成フロー終了)
# - add edge：新しいノードにエッジを追加 or 追加しない
# - choose dest：新しいノードと，どのノードにエッジを追加するのかの確率
#
# 以下が, ３つの識別器を使った生成フローです.

# %% [markdown]
# <!--
# <img src='https://drive.google.com/uc?id=1meLvQov6EbRnCZ8mSGvGaBeo_gjrWPk4' width=70%>
# -->
# <!--
# <img src='https://github.com/machine-perception-robotics-group/MPRGDeepLearningLectureNotebook/blob/master/15_gcn/fig/05_graph_flow.png?raw=true' width=70%>
# -->
# <img src='https://github.com/sirakik/MPRGLecture/blob/master/15_gcn/fig/05_graph_flow.png?raw=true' width=70%>

# %% [markdown]
# 3つのノードを持つグラフの生成過程の例が下の画像です.
# 生成フロー通りに, 識別器が動いているのが，分かると思います.
#
# ここで，各識別器の出力を並べると``[0100010000111]``のようなシーケンスとして表現することが出来ます.
# DGMGはこのシーケンスを教師として学習を行います.
# DGMGはグラフの形そのものを学習するのではなく, そのグラフにたどり着くための識別器の出力順を学習します.

# %% [markdown]
# <!--
# <img src='https://drive.google.com/uc?id=1dgpk8kVBcOB1eJSKwwcxirvGeb6wI9bn' width=70%>
# -->
# <!--
# <img src='https://github.com/machine-perception-robotics-group/MPRGDeepLearningLectureNotebook/blob/master/15_gcn/fig/05_flow.png?raw=true' width=70%>
# -->
# <img src='https://github.com/sirakik/MPRGLecture/blob/master/15_gcn/fig/05_flow.png?raw=true' width=70%>

# %% [markdown]
# # 前準備

# %% [markdown]
# 必要なモジュールをインストール, インポートします.

# %%
pip install dgl  \
pip install networkx
# Out:
# Requirement already satisfied: dgl in /usr/local/lib/python3.6/dist-packages (0.5.1)
# Requirement already satisfied: pip in /usr/local/lib/python3.6/dist-packages (19.3.1)
# Requirement already satisfied: install in /usr/local/lib/python3.6/dist-packages (1.3.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.6/dist-packages (2.5)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from dgl) (1.18.5)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.6/dist-packages (from dgl) (2.23.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from dgl) (1.4.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx) (4.4.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.0->dgl) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.0->dgl) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.0->dgl) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.0->dgl) (2.10)

# %%
import numpy as np
import pickle
import torch
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F
from torch.distributions import Bernoulli, Categorical
import dgl
from dgl.data import MiniGCDataset
from dgl.nn.pytorch import GraphConv
import networkx as nx
import matplotlib.pyplot as plt
# Out:
# Using backend: pytorch

# %% [markdown]
# # データセット　(MiniGCDataset)
#
# ---

# %% [markdown]
# 生成される化合物を直感的に評価することが難しいので,ここでは簡単なグラフ構造の生成を試みます.
# DGLが提供する, MiniGCDatasetを利用します.
# MiniGCDatasetは, 8クラスのグラフ構造を持ち, クラスごとにノード数が異なるグラフを持ちます.

# %% [markdown]
# <!--
# <img src='https://drive.google.com/uc?id=1ALGAgXLqRAKbZ20oXFKYtmZYWjTn99Zv' width=80%>
# -->
# <!--
# <img src='https://github.com/machine-perception-robotics-group/MPRGDeepLearningLectureNotebook/blob/master/15_gcn/fig/05_dataset_overview.png?raw=true' width=80%>
# -->
# <img src='https://github.com/sirakik/MPRGLecture/blob/master/15_gcn/fig/05_dataset_overview.png?raw=true' width=80%>
#
#
# [引用元：https://docs.dgl.ai/en/0.4.x/tutorials/basics/4_batch.html]

# %% [markdown]
# MiniGCDatasetはデータセットではあるものの，データ数や，ノード数を自由に設定し,作成することができます.

# %%
num_per_graph = 100 # クラスごとのデータ数
min_num_node = 10 # 生成されるグラフの最小ノード数
max_num_node = 20 # 生成されるグラフの最大ノード数
dataset = MiniGCDataset(num_per_graph*8, min_num_node, max_num_node)

# %% [markdown]
# データを可視化してみます.データはクラスごとに並んでいます.
# クラスごとのデータ数を100にした場合, 0\~99がクラス0, 100\~199がクラス1のようになっています.
# ``DATA_INDEX``を編集して，可視化してみてください.
# 最小，最大ノード数内でグラフが生成されています.

# %%
DATA_INDEX = 10

graph, label = dataset[DATA_INDEX]
fig, ax = plt.subplots()
nx.draw(graph.to_networkx(), ax=ax, arrows=False)
ax.set_title('Class: {:d}'.format(label))
plt.show()

# %% [markdown]
# ### グラフをシーケンスに変換

# %% [markdown]
# DGMGの教師となるシーケンスを作成します.
# ``adj_to_sequence``関数によって,グラフの隣接行列からシーケンスを作成しています.
# また，学習するクラスを変更した実験をするため，シーケンスを生成する手順を関数化しておき, 学習の直前で教師を作成します.

# %%
def adj_to_sequence(adj):
    sequence = []
    for node in range(len(adj)):
        sequence.append(0)  # add node
        for dest in range(node):
            if adj[node][dest] == 1:
                sequence.append(0)  # add edge
                sequence.append(dest)  # add dest node
        sequence.append(1)  # stop add edge
    sequence.append(1)  # stop add node
    return sequence

def make_dataset(class_label):
    list_sequence = []
    for cla in class_label:
        s_index = cla * num_per_graph
        for index in range(s_index, s_index+num_per_graph):
            graph, _ = dataset[index]
            tril = np.ones((graph.number_of_nodes(), graph.number_of_nodes()))
            tril = np.tril(tril, k=-1)
            adj = graph.adjacency_matrix().to_dense().numpy()
            adj = tril*adj
            sequence = adj_to_sequence(adj)
            list_sequence.append(sequence)
    with open('sequence_data.p', 'wb') as f:
        pickle.dump(list_sequence, f)

# %% [markdown]
# データを読み込む関数です.

# %%
class MiniGCDataset(torch.utils.data.Dataset):
    def __init__(self, fname='sequence_data.p'):
        super(MiniGCDataset, self).__init__()
        with open(fname, 'rb') as f:
            self.data = pickle.load(f)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        return self.data[index]

# %% [markdown]
# # DGMG実装
#
# ---

# %% [markdown]
# ### graph embedding

# %% [markdown]
# add nodeやadd edgeの識別器（全結合層）に渡すために, グラフ特徴を埋め込み表現に直します.
#
# \begin{equation}
# {\bf h}_{G}=\sum_{n\in \bf V} f_e({\bf h}_v) \odot sigmoid(g_e({\bf h}_v))
# \end{equation}
#
# $f_e(\cdot),g_e(\cdot)$は全結合層です.重要なノードを考慮しつつ特徴を埋め込みます.

# %% [markdown]
# <!--
# <img src='https://drive.google.com/uc?id=1fBUApZyGIHXUbWG6lVTYKt9gwDSevtxV' width=40%>
# -->
# <!--
# <img src='https://github.com/machine-perception-robotics-group/MPRGDeepLearningLectureNotebook/blob/master/15_gcn/fig/05_embed.png?raw=true' width=40%>
# -->
# <img src='https://github.com/sirakik/MPRGLecture/blob/master/15_gcn/fig/05_graph_embed.png?raw=true' width=40%>

# %%
class GraphEmbed(nn.Module):
    def __init__(self, node_hidden_size):
        super(GraphEmbed, self).__init__()
        self.graph_hidden_size = 2 * node_hidden_size
        self.node_gating = nn.Sequential(
            nn.Linear(node_hidden_size, 1),
            nn.Sigmoid())
        self.node_to_graph = nn.Linear(node_hidden_size,
                                       self.graph_hidden_size)

    def forward(self, g):
        # ノード数が0(生成の最初)のときは空の特徴を返します.
        if g.number_of_nodes() == 0:
            return torch.zeros(1, self.graph_hidden_size)
        else:
            hvs = g.ndata['hv']
            hvs = (self.node_gating(hvs) * self.node_to_graph(hvs)).sum(0, keepdim=True)
            return hvs

# %% [markdown]
# ### feature extractor

# %% [markdown]
# feature extractorは生成フロー中で,エッジが追加された後に使用され,現状のグラフ構造を理解します.
# DGMGでは特徴抽出器としてGGNN(GRUを使ったノード特徴集約手法)を使っています.
# Graph convolutionより少しだけ前の手法であり, GRUを利用するため勾配消失・爆発が起こりやすい特徴もあります.
# せっかくなのでGraph convolutionに変更してみます.
# 今回は,DGLにあらかじめ実装されている``GraphConv``関数を利用します.

# %% [markdown]
# <!--
# <img src='https://drive.google.com/uc?id=12NPl3B8skdJ3qsZXwKiotlgFB94gCv1v' width=40%>
# -->
# <!--
# <img src='https://github.com/machine-perception-robotics-group/MPRGDeepLearningLectureNotebook/blob/master/15_gcn/fig/05_DGMG_feature_extractor.png?raw=true' width=40%>
# -->
# <img src='https://github.com/sirakik/MPRGLecture/blob/master/15_gcn/fig/05_DGMG_feature_extractor.png?raw=true' width=40%>

# %%
class FeatureExtractor(nn.Module):
    def __init__(self, num_hidden_size):
        super(FeatureExtractor, self).__init__()
        self.gc1 = GraphConv(num_hidden_size, 2 * num_hidden_size)
        self.gc2 = GraphConv(2 * num_hidden_size, num_hidden_size)
        self.sigmoid = nn.Sigmoid()

    def forward(self, g):
        if g.number_of_edges() == 0:
            return g
        else:
            h = self.gc1(g, g.ndata['hv'])
            h = self.sigmoid(h)
            g.ndata['hv'] = self.gc2(g, h)
            return g

# %% [markdown]
# ### add node

# %% [markdown]
# グラフに新しいノードを追加するか, しないかの2クラス分類器です.
# graph embedを通り, その出力値をadd node(全結合層)を通します.
# 化合物生成の場合, 新しいノード(原子)のクラス(H, He, Li, Be...)を予測する必要がありますが,ここでは必要ありません.
# クラスではなく, 新しいノード特徴を生成するのみです(``itinialize_node``)

# %% [markdown]
# <!--
# <img src='https://drive.google.com/uc?id=1pK1QNLiaF7qHFMBXS6rbmm94glgUpGND' width=60%>
# -->
# <!--
# <img src='https://github.com/machine-perception-robotics-group/MPRGDeepLearningLectureNotebook/blob/master/15_gcn/fig/05_graph_embed_add_node.png?raw=true' width=60%>
# -->
# <img src='https://github.com/sirakik/MPRGLecture/blob/master/15_gcn/fig/05_graph_embed_add_node.png?raw=true' width=60%>

# %%
class AddNode(nn.Module):
    def __init__(self, graph_embed, node_hidden_size):
        super(AddNode, self).__init__()
        self.graph_embed = graph_embed
        self.add_node = nn.Linear(graph_embed.graph_hidden_size, 1)
        self.sigmoid = nn.Sigmoid()
        # initialize node
        self.node_embed = nn.Embedding(1, node_hidden_size)
        self.initialize_hv = nn.Linear(graph_embed.graph_hidden_size, node_hidden_size)
        self.activation_node = torch.zeros(1, 2 * node_hidden_size)

    def prepare_training(self):
        self.log_prob = 0

    def initialize_node(self, g, graph_feature):
        last_node = g.number_of_nodes() - 1
        hv_init = self.initialize_hv(graph_feature)
        g.nodes[last_node].data['hv'] = hv_init
        g.nodes[last_node].data['a'] = self.activation_node
        return g

    def bernoulli_action_prob(self, logit, action):
        if action == 0:
            return F.logsigmoid(-logit)
        else:
            return F.logsigmoid(logit)

    def forward(self, g, action=None):
        graph_feature = self.graph_embed(g)
        logit = self.add_node(graph_feature)

        if self.training:
            self.log_prob += self.bernoulli_action_prob(logit, action)
        else:
            prob = self.sigmoid(logit)
            action = Bernoulli(prob).sample().item()

        stop = bool(action == 1)  # 1はstop

        if not stop:
            g.add_nodes(1)
            g = self.initialize_node(g, graph_feature)

        return g, stop

# %% [markdown]
# ### add edge

# %% [markdown]
# 新しいノードにエッジを追加するか, しないかの2クラス分類器です.
# 新しくノードが追加されたため, グラフの埋め込みをもう一度行います.
# 埋め込み表現された特徴に, 新しいノード特徴を結合しadd edgeに通します.

# %% [markdown]
# <!--
# <img src='https://drive.google.com/uc?id=16iALJ82t-1QydVsYwWTnyjwgrXdO3zHK' width=60%>
# -->
# <!--
# <img src='https://github.com/machine-perception-robotics-group/MPRGDeepLearningLectureNotebook/blob/master/15_gcn/fig/05_graph_embed_add_edge.png?raw=true' width=60%>
# -->
# <img src='https://github.com/sirakik/MPRGLecture/blob/master/15_gcn/fig/05_graph_embed_add_edge.png?raw=true' width=60%>

# %%
class AddEdge(nn.Module):
    def __init__(self, graph_embed, node_hidden_size):
        super(AddEdge, self).__init__()
        self.graph_embed = graph_embed
        self.add_edge = nn.Linear(graph_embed.graph_hidden_size + node_hidden_size, 1)
        self.sigmoid = nn.Sigmoid()

    def prepare_training(self):
        self.log_prob = 0

    def bernoulli_action_prob(self, logit, action):
        if action == 0:
            return F.logsigmoid(-logit)
        else:
            return F.logsigmoid(logit)

    def forward(self, g, action=None):
        graph_feature = self.graph_embed(g)
        last_node_feature = g.nodes[g.number_of_nodes() - 1].data['hv']
        logit = self.add_edge(torch.cat([graph_feature, last_node_feature], dim=1))

        if self.training:
            self.log_prob += self.bernoulli_action_prob(logit, action)
        else:
            prob = self.sigmoid(logit)
            action = Bernoulli(prob).sample().item()

        to_add_edge = bool(action == 0)

        return to_add_edge

# %% [markdown]
# ### choose dest

# %% [markdown]
# add edgeによって,エッジを追加すると判断された場合に,どのノードにエッジを追加するかを決める多クラス分類器です.
# エッジが追加された後に,feature extractorに通します.

# %% [markdown]
# <!--
# <img src='https://drive.google.com/uc?id=14_6edweMFguIJenWQ18xciHg3zg5gcsD' width=70%>
# -->
# <!--
# <img src='https://github.com/machine-perception-robotics-group/MPRGDeepLearningLectureNotebook/blob/master/15_gcn/fig/05_choose_dest_feature_extractor.png?raw=true' width=70%>
# -->
# <img src='https://github.com/sirakik/MPRGLecture/blob/master/15_gcn/fig/05_choose_dest_feature_extractor.png?raw=true' width=70%>

# %%
class ChooseDest(nn.Module):
    def __init__(self, graph_prop, node_hidden_size):
        super(ChooseDest, self).__init__()
        self.graph_prop = graph_prop
        self.choose_dest = nn.Linear(2 * node_hidden_size, 1)
        self.softmax = nn.Softmax(dim=1)

    def prepare_training(self):
        self.log_prob = 0

    def initialize_edge(self, g, src_list, dest_list):
        edge_repr = torch.ones(len(src_list), 1)
        g.edges[src_list, dest_list].data['he'] = edge_repr
        return g

    def forward(self, g, dest=None):
        last_node = g.number_of_nodes() - 1
        possible_dest = range(last_node)

        last_node_feature_expand = g.nodes[last_node].data['hv'].expand(last_node, -1)
        possible_dest_feature = g.nodes[possible_dest].data['hv']

        dest_score = self.choose_dest(
            torch.cat([possible_dest_feature, last_node_feature_expand], dim=-1
        )).view(1, -1)
        dest_prob = self.softmax(dest_score)

        if self.training:
            dest = int(dest.item())
            if dest_prob.nelement() > 1:
                self.log_prob += F.log_softmax(dest_score, dim=1)[:, dest:dest+1]
        else:
            dest = Categorical(dest_prob).sample().item()

        if not g.has_edge_between(last_node, dest):
            src_list = [last_node, dest]
            dest_list = [dest, last_node]
            g.add_edges(src_list, dest_list)
            g = self.initialize_edge(g, src_list, dest_list)
        g = self.graph_prop(g)
        return g

# %% [markdown]
# ### DGMG

# %% [markdown]
# 生成フローを定義しています.
# 学習時は，シーケンス（真値）を与え,グラフ生成をします.
# 仮に,識別器の答えが真値と違った場合でも,真値が出力されたと仮定して,生成を続けます.

# %% [markdown]
# <!--
# <img src='https://drive.google.com/uc?id=1meLvQov6EbRnCZ8mSGvGaBeo_gjrWPk4' width=70%>
# -->
# <!--
# <img src='https://github.com/machine-perception-robotics-group/MPRGDeepLearningLectureNotebook/blob/master/15_gcn/fig/05_graph_flow.png?raw=true' width=70%>
# -->
# <img src='https://github.com/sirakik/MPRGLecture/blob/master/15_gcn/fig/05_graph_flow.png?raw=true' width=70%>

# %%
def weights_init(m):
    if isinstance(m, nn.Linear):
        init.xavier_normal_(m.weight.data)
        init.normal_(m.bias.data)
    elif isinstance(m, nn.GRUCell):
        for param in m.parameters():
            if len(param.shape) >= 2:
                init.orthogonal_(param.data)
            else:
                init.normal_(param.data)

class DGMG(nn.Module):
    def __init__(self, max_num_node, node_hidden_size):
        super(DGMG, self).__init__()
        self.max_num_node = max_num_node
        self.graph_embed = GraphEmbed(node_hidden_size)
        self.graph_prop = FeatureExtractor(node_hidden_size)
        self.add_node = AddNode(self.graph_embed, node_hidden_size)
        self.add_edge = AddEdge(self.graph_embed, node_hidden_size)
        self.choose_dest = ChooseDest(self.graph_prop, node_hidden_size)
        self.init_weight()

    def init_weight(self):
        self.graph_embed.apply(weights_init)
        self.graph_prop.apply(weights_init)
        self.add_node.apply(weights_init)
        self.add_edge.apply(weights_init)
        self.choose_dest.apply(weights_init)

    @property
    def action_step(self):
        last_step_count = self.step_count
        self.step_count += 1
        return last_step_count

    def prepare_for_train(self):
        self.step_count = 0
        self.add_node.prepare_training()
        self.add_edge.prepare_training()
        self.choose_dest.prepare_training()

    def get_log_prob(self):
        return self.add_node.log_prob + self.add_edge.log_prob + self.choose_dest.log_prob

    def forward_train(self, sequence):
        self.prepare_for_train()
        self.g, stop = self.add_node(self.g, sequence[self.action_step])
        while not stop:
            to_add_edge = self.add_edge(self.g, sequence[self.action_step])
            while to_add_edge:
                self.g = self.choose_dest(self.g, sequence[self.action_step])
                to_add_edge = self.add_edge(self.g, sequence[self.action_step])
            self.g, stop = self.add_node(self.g, sequence[self.action_step])
        return self.get_log_prob()

    def forward_eval(self):
        self.g, stop = self.add_node(self.g)
        while (not stop) and (self.g.number_of_nodes() < self.max_num_node + 1):
            num_dest = 0
            to_add_edge = self.add_edge(self.g)
            while to_add_edge and (num_dest < self.g.number_of_nodes() - 1):
                self.g = self.choose_dest(self.g)
                num_dest += 1
                to_add_edge = self.add_edge(self.g)
            self.g, stop = self.add_node(self.g)
        return self.g

    def forward(self, sequence=None):
        self.g = dgl.DGLGraph()
        self.g.set_n_initializer(dgl.frame.zero_initializer)
        self.g.set_e_initializer(dgl.frame.zero_initializer)
        if self.training:
            return self.forward_train(sequence)
        else:
            return self.forward_eval()

# %% [markdown]
# # 学習
#
# ---

# %% [markdown]
# 各識別器のアクション$a_1,\dots,a_T$は,以下のように確率として表現できます.
#
# \begin{equation}
# p(a_1,\dots,a_T)=p(a_1)p(a_2|a_1)\dots p(a_T|a_1,\dots,a_{T-1})
# \end{equation}
#
# この確率をパラメータの関数と見なすことができるので,
# MLE　Loss(Maximum Likelihood Estimation:最尤推定)によってモデルを最適化させます.
#
# \begin{equation}
# E = -\log p(a_1,\dots,a_T) = -\sum^T_t \log p(a_t|a_1,\dots,a_{t-1})
# \end{equation}

# %% [markdown]
# また, 学習させるグラフクラスを選択することができます.
# ``make_dataset(class_label=[])``の配列にグラフラベルを入力してください.
# 複数のグラフを学習させることもできます.
# 複数のグラフを学習させた場合,　各グラフの特徴を考慮したグラフが生成されるはずです.

# %%
NUM_EPOCH = 100
BATCH_SIZE = 32

make_dataset(class_label=[2])
# data loaderのバッチサイズは1で固定です
data_loader = torch.utils.data.DataLoader(MiniGCDataset(),
                                          batch_size=1,
                                          shuffle=True)

model = DGMG(max_num_node,
                node_hidden_size=16)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

#model.train()
for epoch in range(1, NUM_EPOCH+1):
    batch_count = 0
    batch_loss = 0
    optimizer.zero_grad()
    for i, data in enumerate(data_loader):
        data = data
        log_prob = model(sequence=data)
        prob = log_prob.detach().exp()

        loss = - log_prob / BATCH_SIZE
        loss.backward()
        batch_loss += loss.item()
        batch_count += 1

        if batch_count % BATCH_SIZE == 0:
            optimizer.step()
            optimizer.zero_grad()
            print('# Epoch: {} | Batch: [{}/{}] | loss: {:.4f}'.format(epoch, i+1, len(data_loader), batch_loss/BATCH_SIZE))
            batch_loss = 0
# Out:
# /usr/local/lib/python3.6/dist-packages/dgl/base.py:45: DGLWarning: Recommend creating graphs by `dgl.graph(data)` instead of `dgl.DGLGraph(data)`.
#   return warnings.warn(message, category=category, stacklevel=1)
# /usr/local/lib/python3.6/dist-packages/dgl/base.py:45: DGLWarning: DGLGraph.has_edge_between is deprecated. Please use DGLGraph.has_edges_between
#   return warnings.warn(message, category=category, stacklevel=1)
# # Epoch: 1 | Batch: [32/100] | loss: 9.6481
# # Epoch: 1 | Batch: [64/100] | loss: 3.2091
# # Epoch: 1 | Batch: [96/100] | loss: 3.4976
# # Epoch: 2 | Batch: [32/100] | loss: 3.2026
# # Epoch: 2 | Batch: [64/100] | loss: 2.6634
# # Epoch: 2 | Batch: [96/100] | loss: 2.5823
# # Epoch: 3 | Batch: [32/100] | loss: 2.5244
# # Epoch: 3 | Batch: [64/100] | loss: 2.3182
# # Epoch: 3 | Batch: [96/100] | loss: 2.4052
# # Epoch: 4 | Batch: [32/100] | loss: 2.3978
# # Epoch: 4 | Batch: [64/100] | loss: 2.7546
# # Epoch: 4 | Batch: [96/100] | loss: 2.2733
# # Epoch: 5 | Batch: [32/100] | loss: 2.5374
# # Epoch: 5 | Batch: [64/100] | loss: 2.3465
# # Epoch: 5 | Batch: [96/100] | loss: 2.5268
# # Epoch: 6 | Batch: [32/100] | loss: 2.4689
# # Epoch: 6 | Batch: [64/100] | loss: 2.4182
# # Epoch: 6 | Batch: [96/100] | loss: 2.3696
# # Epoch: 7 | Batch: [32/100] | loss: 2.3315
# # Epoch: 7 | Batch: [64/100] | loss: 2.4521
# # Epoch: 7 | Batch: [96/100] | loss: 2.2546
# # Epoch: 8 | Batch: [32/100] | loss: 2.1925
# # Epoch: 8 | Batch: [64/100] | loss: 2.3271
# # Epoch: 8 | Batch: [96/100] | loss: 2.3264
# # Epoch: 9 | Batch: [32/100] | loss: 2.2912
# # Epoch: 9 | Batch: [64/100] | loss: 2.2198
# # Epoch: 9 | Batch: [96/100] | loss: 2.2186
# # Epoch: 10 | Batch: [32/100] | loss: 2.2322
# # Epoch: 10 | Batch: [64/100] | loss: 2.2489
# # Epoch: 10 | Batch: [96/100] | loss: 2.1288
# # Epoch: 11 | Batch: [32/100] | loss: 2.2655
# # Epoch: 11 | Batch: [64/100] | loss: 2.2083
# # Epoch: 11 | Batch: [96/100] | loss: 2.1252
# # Epoch: 12 | Batch: [32/100] | loss: 2.1816
# # Epoch: 12 | Batch: [64/100] | loss: 2.1937
# # Epoch: 12 | Batch: [96/100] | loss: 2.2200
# # Epoch: 13 | Batch: [32/100] | loss: 2.3040
# # Epoch: 13 | Batch: [64/100] | loss: 2.1433
# # Epoch: 13 | Batch: [96/100] | loss: 2.0518
# # Epoch: 14 | Batch: [32/100] | loss: 2.2175
# # Epoch: 14 | Batch: [64/100] | loss: 2.0574
# # Epoch: 14 | Batch: [96/100] | loss: 2.0894
# # Epoch: 15 | Batch: [32/100] | loss: 2.1021
# # Epoch: 15 | Batch: [64/100] | loss: 2.0385
# # Epoch: 15 | Batch: [96/100] | loss: 2.1458
# # Epoch: 16 | Batch: [32/100] | loss: 1.9427
# # Epoch: 16 | Batch: [64/100] | loss: 2.2068
# # Epoch: 16 | Batch: [96/100] | loss: 2.0566
# # Epoch: 17 | Batch: [32/100] | loss: 2.0013
# # Epoch: 17 | Batch: [64/100] | loss: 1.9602
# # Epoch: 17 | Batch: [96/100] | loss: 2.0799
# # Epoch: 18 | Batch: [32/100] | loss: 2.0524
# # Epoch: 18 | Batch: [64/100] | loss: 2.0809
# # Epoch: 18 | Batch: [96/100] | loss: 1.7846
# # Epoch: 19 | Batch: [32/100] | loss: 1.8943
# # Epoch: 19 | Batch: [64/100] | loss: 1.9280
# # Epoch: 19 | Batch: [96/100] | loss: 1.8736
# # Epoch: 20 | Batch: [32/100] | loss: 1.9441
# # Epoch: 20 | Batch: [64/100] | loss: 1.7640
# # Epoch: 20 | Batch: [96/100] | loss: 1.7931
# # Epoch: 21 | Batch: [32/100] | loss: 1.7255
# # Epoch: 21 | Batch: [64/100] | loss: 1.6665
# # Epoch: 21 | Batch: [96/100] | loss: 1.8212
# # Epoch: 22 | Batch: [32/100] | loss: 1.6029
# # Epoch: 22 | Batch: [64/100] | loss: 1.6138
# # Epoch: 22 | Batch: [96/100] | loss: 1.7998
# # Epoch: 23 | Batch: [32/100] | loss: 1.6588
# # Epoch: 23 | Batch: [64/100] | loss: 1.6119
# # Epoch: 23 | Batch: [96/100] | loss: 1.4975
# # Epoch: 24 | Batch: [32/100] | loss: 1.5261
# # Epoch: 24 | Batch: [64/100] | loss: 1.4335
# # Epoch: 24 | Batch: [96/100] | loss: 1.6015
# # Epoch: 25 | Batch: [32/100] | loss: 1.4775
# # Epoch: 25 | Batch: [64/100] | loss: 1.4564
# # Epoch: 25 | Batch: [96/100] | loss: 1.5285
# # Epoch: 26 | Batch: [32/100] | loss: 1.5037
# # Epoch: 26 | Batch: [64/100] | loss: 1.4222
# # Epoch: 26 | Batch: [96/100] | loss: 1.4905
# # Epoch: 27 | Batch: [32/100] | loss: 1.5415
# # Epoch: 27 | Batch: [64/100] | loss: 1.6246
# # Epoch: 27 | Batch: [96/100] | loss: 1.5557
# # Epoch: 28 | Batch: [32/100] | loss: 1.4271
# # Epoch: 28 | Batch: [64/100] | loss: 1.4191
# # Epoch: 28 | Batch: [96/100] | loss: 1.3968
# # Epoch: 29 | Batch: [32/100] | loss: 1.2723
# # Epoch: 29 | Batch: [64/100] | loss: 1.4306
# # Epoch: 29 | Batch: [96/100] | loss: 1.4008
# # Epoch: 30 | Batch: [32/100] | loss: 1.3723
# # Epoch: 30 | Batch: [64/100] | loss: 1.3327
# # Epoch: 30 | Batch: [96/100] | loss: 1.2759
# # Epoch: 31 | Batch: [32/100] | loss: 1.2903
# # Epoch: 31 | Batch: [64/100] | loss: 1.2976
# # Epoch: 31 | Batch: [96/100] | loss: 1.2951
# # Epoch: 32 | Batch: [32/100] | loss: 1.2432
# # Epoch: 32 | Batch: [64/100] | loss: 1.2937
# # Epoch: 32 | Batch: [96/100] | loss: 1.2143
# # Epoch: 33 | Batch: [32/100] | loss: 1.1637
# # Epoch: 33 | Batch: [64/100] | loss: 1.2566
# # Epoch: 33 | Batch: [96/100] | loss: 1.2713
# # Epoch: 34 | Batch: [32/100] | loss: 1.2616
# # Epoch: 34 | Batch: [64/100] | loss: 1.1292
# # Epoch: 34 | Batch: [96/100] | loss: 1.1639
# # Epoch: 35 | Batch: [32/100] | loss: 1.1138
# # Epoch: 35 | Batch: [64/100] | loss: 1.1520
# # Epoch: 35 | Batch: [96/100] | loss: 1.1456
# # Epoch: 36 | Batch: [32/100] | loss: 1.1461
# # Epoch: 36 | Batch: [64/100] | loss: 1.0491
# # Epoch: 36 | Batch: [96/100] | loss: 1.0708
# # Epoch: 37 | Batch: [32/100] | loss: 1.0968
# # Epoch: 37 | Batch: [64/100] | loss: 1.0342
# # Epoch: 37 | Batch: [96/100] | loss: 1.0157
# # Epoch: 38 | Batch: [32/100] | loss: 1.0524
# # Epoch: 38 | Batch: [64/100] | loss: 0.9935
# # Epoch: 38 | Batch: [96/100] | loss: 0.9579
# # Epoch: 39 | Batch: [32/100] | loss: 0.9584
# # Epoch: 39 | Batch: [64/100] | loss: 0.9188
# # Epoch: 39 | Batch: [96/100] | loss: 0.9420
# # Epoch: 40 | Batch: [32/100] | loss: 0.9007
# # Epoch: 40 | Batch: [64/100] | loss: 0.9049
# # Epoch: 40 | Batch: [96/100] | loss: 0.8644
# # Epoch: 41 | Batch: [32/100] | loss: 0.8502
# # Epoch: 41 | Batch: [64/100] | loss: 0.9021
# # Epoch: 41 | Batch: [96/100] | loss: 0.7519
# # Epoch: 42 | Batch: [32/100] | loss: 0.7993
# # Epoch: 42 | Batch: [64/100] | loss: 0.7996
# # Epoch: 42 | Batch: [96/100] | loss: 0.7562
# # Epoch: 43 | Batch: [32/100] | loss: 0.7668
# # Epoch: 43 | Batch: [64/100] | loss: 0.7896
# # Epoch: 43 | Batch: [96/100] | loss: 0.7041
# # Epoch: 44 | Batch: [32/100] | loss: 0.7220
# # Epoch: 44 | Batch: [64/100] | loss: 0.7411
# # Epoch: 44 | Batch: [96/100] | loss: 0.6791
# # Epoch: 45 | Batch: [32/100] | loss: 0.7001
# # Epoch: 45 | Batch: [64/100] | loss: 0.6898
# # Epoch: 45 | Batch: [96/100] | loss: 0.6109
# # Epoch: 46 | Batch: [32/100] | loss: 0.6341
# # Epoch: 46 | Batch: [64/100] | loss: 0.6361
# # Epoch: 46 | Batch: [96/100] | loss: 0.6268
# # Epoch: 47 | Batch: [32/100] | loss: 0.6232
# # Epoch: 47 | Batch: [64/100] | loss: 0.6099
# # Epoch: 47 | Batch: [96/100] | loss: 0.5720
# # Epoch: 48 | Batch: [32/100] | loss: 0.5920
# # Epoch: 48 | Batch: [64/100] | loss: 0.5866
# # Epoch: 48 | Batch: [96/100] | loss: 0.5661
# # Epoch: 49 | Batch: [32/100] | loss: 0.5501
# # Epoch: 49 | Batch: [64/100] | loss: 0.5503
# # Epoch: 49 | Batch: [96/100] | loss: 0.5673
# # Epoch: 50 | Batch: [32/100] | loss: 0.5226
# # Epoch: 50 | Batch: [64/100] | loss: 0.5609
# # Epoch: 50 | Batch: [96/100] | loss: 0.5512
# # Epoch: 51 | Batch: [32/100] | loss: 0.5517
# # Epoch: 51 | Batch: [64/100] | loss: 0.5375
# # Epoch: 51 | Batch: [96/100] | loss: 0.5042
# # Epoch: 52 | Batch: [32/100] | loss: 0.5310
# # Epoch: 52 | Batch: [64/100] | loss: 0.5040
# # Epoch: 52 | Batch: [96/100] | loss: 0.5316
# # Epoch: 53 | Batch: [32/100] | loss: 0.5321
# # Epoch: 53 | Batch: [64/100] | loss: 0.5242
# # Epoch: 53 | Batch: [96/100] | loss: 0.4973
# # Epoch: 54 | Batch: [32/100] | loss: 0.5180
# # Epoch: 54 | Batch: [64/100] | loss: 0.5028
# # Epoch: 54 | Batch: [96/100] | loss: 0.5120
# # Epoch: 55 | Batch: [32/100] | loss: 0.5233
# # Epoch: 55 | Batch: [64/100] | loss: 0.4957
# # Epoch: 55 | Batch: [96/100] | loss: 0.4968
# # Epoch: 56 | Batch: [32/100] | loss: 0.5228
# # Epoch: 56 | Batch: [64/100] | loss: 0.5022
# # Epoch: 56 | Batch: [96/100] | loss: 0.5036
# # Epoch: 57 | Batch: [32/100] | loss: 0.4944
# # Epoch: 57 | Batch: [64/100] | loss: 0.4629
# # Epoch: 57 | Batch: [96/100] | loss: 0.6084
# # Epoch: 58 | Batch: [32/100] | loss: 0.5182
# # Epoch: 58 | Batch: [64/100] | loss: 0.5791
# # Epoch: 58 | Batch: [96/100] | loss: 0.5441
# # Epoch: 59 | Batch: [32/100] | loss: 0.4962
# # Epoch: 59 | Batch: [64/100] | loss: 0.5329
# # Epoch: 59 | Batch: [96/100] | loss: 0.4727
# # Epoch: 60 | Batch: [32/100] | loss: 0.4921
# # Epoch: 60 | Batch: [64/100] | loss: 0.4986
# # Epoch: 60 | Batch: [96/100] | loss: 0.4979
# # Epoch: 61 | Batch: [32/100] | loss: 0.4874
# # Epoch: 61 | Batch: [64/100] | loss: 0.4614
# # Epoch: 61 | Batch: [96/100] | loss: 0.5144
# # Epoch: 62 | Batch: [32/100] | loss: 0.4966
# # Epoch: 62 | Batch: [64/100] | loss: 0.4971
# # Epoch: 62 | Batch: [96/100] | loss: 0.5051
# # Epoch: 63 | Batch: [32/100] | loss: 0.4819
# # Epoch: 63 | Batch: [64/100] | loss: 0.4741
# # Epoch: 63 | Batch: [96/100] | loss: 0.5059
# # Epoch: 64 | Batch: [32/100] | loss: 0.5099
# # Epoch: 64 | Batch: [64/100] | loss: 0.4860
# # Epoch: 64 | Batch: [96/100] | loss: 0.5165
# # Epoch: 65 | Batch: [32/100] | loss: 0.4990
# # Epoch: 65 | Batch: [64/100] | loss: 0.4678
# # Epoch: 65 | Batch: [96/100] | loss: 0.5059
# # Epoch: 66 | Batch: [32/100] | loss: 0.5039
# # Epoch: 66 | Batch: [64/100] | loss: 0.4611
# # Epoch: 66 | Batch: [96/100] | loss: 0.4750
# # Epoch: 67 | Batch: [32/100] | loss: 0.4818
# # Epoch: 67 | Batch: [64/100] | loss: 0.4690
# # Epoch: 67 | Batch: [96/100] | loss: 0.4648
# # Epoch: 68 | Batch: [32/100] | loss: 0.4904
# # Epoch: 68 | Batch: [64/100] | loss: 0.4662
# # Epoch: 68 | Batch: [96/100] | loss: 0.4539
# # Epoch: 69 | Batch: [32/100] | loss: 0.4715
# # Epoch: 69 | Batch: [64/100] | loss: 0.4674
# # Epoch: 69 | Batch: [96/100] | loss: 0.4564
# # Epoch: 70 | Batch: [32/100] | loss: 0.4579
# # Epoch: 70 | Batch: [64/100] | loss: 0.4601
# # Epoch: 70 | Batch: [96/100] | loss: 0.4594
# # Epoch: 71 | Batch: [32/100] | loss: 0.4439
# # Epoch: 71 | Batch: [64/100] | loss: 0.4494
# # Epoch: 71 | Batch: [96/100] | loss: 0.4638
# # Epoch: 72 | Batch: [32/100] | loss: 0.4503
# # Epoch: 72 | Batch: [64/100] | loss: 0.4545
# # Epoch: 72 | Batch: [96/100] | loss: 0.4503
# # Epoch: 73 | Batch: [32/100] | loss: 0.4629
# # Epoch: 73 | Batch: [64/100] | loss: 0.4406
# # Epoch: 73 | Batch: [96/100] | loss: 0.4468
# # Epoch: 74 | Batch: [32/100] | loss: 0.4361
# # Epoch: 74 | Batch: [64/100] | loss: 0.4528
# # Epoch: 74 | Batch: [96/100] | loss: 0.4396
# # Epoch: 75 | Batch: [32/100] | loss: 0.4756
# # Epoch: 75 | Batch: [64/100] | loss: 0.4563
# # Epoch: 75 | Batch: [96/100] | loss: 0.4334
# # Epoch: 76 | Batch: [32/100] | loss: 0.4611
# # Epoch: 76 | Batch: [64/100] | loss: 0.4598
# # Epoch: 76 | Batch: [96/100] | loss: 0.4655
# # Epoch: 77 | Batch: [32/100] | loss: 0.4912
# # Epoch: 77 | Batch: [64/100] | loss: 0.4514
# # Epoch: 77 | Batch: [96/100] | loss: 0.4592
# # Epoch: 78 | Batch: [32/100] | loss: 0.4536
# # Epoch: 78 | Batch: [64/100] | loss: 0.4549
# # Epoch: 78 | Batch: [96/100] | loss: 0.4675
# # Epoch: 79 | Batch: [32/100] | loss: 0.4630
# # Epoch: 79 | Batch: [64/100] | loss: 0.4538
# # Epoch: 79 | Batch: [96/100] | loss: 0.4610
# # Epoch: 80 | Batch: [32/100] | loss: 0.4543
# # Epoch: 80 | Batch: [64/100] | loss: 0.4522
# # Epoch: 80 | Batch: [96/100] | loss: 0.4550
# # Epoch: 81 | Batch: [32/100] | loss: 0.4550
# # Epoch: 81 | Batch: [64/100] | loss: 0.4493
# # Epoch: 81 | Batch: [96/100] | loss: 0.4453
# # Epoch: 82 | Batch: [32/100] | loss: 0.4432
# # Epoch: 82 | Batch: [64/100] | loss: 0.4582
# # Epoch: 82 | Batch: [96/100] | loss: 0.4324
# # Epoch: 83 | Batch: [32/100] | loss: 0.4393
# # Epoch: 83 | Batch: [64/100] | loss: 0.4300
# # Epoch: 83 | Batch: [96/100] | loss: 0.4415
# # Epoch: 84 | Batch: [32/100] | loss: 0.4454
# # Epoch: 84 | Batch: [64/100] | loss: 0.4320
# # Epoch: 84 | Batch: [96/100] | loss: 0.4262
# # Epoch: 85 | Batch: [32/100] | loss: 0.4506
# # Epoch: 85 | Batch: [64/100] | loss: 0.4370
# # Epoch: 85 | Batch: [96/100] | loss: 0.4120
# # Epoch: 86 | Batch: [32/100] | loss: 0.4263
# # Epoch: 86 | Batch: [64/100] | loss: 0.4368
# # Epoch: 86 | Batch: [96/100] | loss: 0.4191
# # Epoch: 87 | Batch: [32/100] | loss: 0.4239
# # Epoch: 87 | Batch: [64/100] | loss: 0.4304
# # Epoch: 87 | Batch: [96/100] | loss: 0.4083
# # Epoch: 88 | Batch: [32/100] | loss: 0.4259
# # Epoch: 88 | Batch: [64/100] | loss: 0.4106
# # Epoch: 88 | Batch: [96/100] | loss: 0.4198
# # Epoch: 89 | Batch: [32/100] | loss: 0.4199
# # Epoch: 89 | Batch: [64/100] | loss: 0.4102
# # Epoch: 89 | Batch: [96/100] | loss: 0.4128
# # Epoch: 90 | Batch: [32/100] | loss: 0.4011
# # Epoch: 90 | Batch: [64/100] | loss: 0.4140
# # Epoch: 90 | Batch: [96/100] | loss: 0.4202
# # Epoch: 91 | Batch: [32/100] | loss: 0.4078
# # Epoch: 91 | Batch: [64/100] | loss: 0.4110
# # Epoch: 91 | Batch: [96/100] | loss: 0.4058
# # Epoch: 92 | Batch: [32/100] | loss: 0.4117
# # Epoch: 92 | Batch: [64/100] | loss: 0.4059
# # Epoch: 92 | Batch: [96/100] | loss: 0.3981
# # Epoch: 93 | Batch: [32/100] | loss: 0.4154
# # Epoch: 93 | Batch: [64/100] | loss: 0.4014
# # Epoch: 93 | Batch: [96/100] | loss: 0.3995
# # Epoch: 94 | Batch: [32/100] | loss: 0.4027
# # Epoch: 94 | Batch: [64/100] | loss: 0.4126
# # Epoch: 94 | Batch: [96/100] | loss: 0.3912
# # Epoch: 95 | Batch: [32/100] | loss: 0.3989
# # Epoch: 95 | Batch: [64/100] | loss: 0.4024
# # Epoch: 95 | Batch: [96/100] | loss: 0.4131
# # Epoch: 96 | Batch: [32/100] | loss: 0.3819
# # Epoch: 96 | Batch: [64/100] | loss: 0.3967
# # Epoch: 96 | Batch: [96/100] | loss: 0.4165
# # Epoch: 97 | Batch: [32/100] | loss: 0.4020
# # Epoch: 97 | Batch: [64/100] | loss: 0.3935
# # Epoch: 97 | Batch: [96/100] | loss: 0.3972
# # Epoch: 98 | Batch: [32/100] | loss: 0.3984
# # Epoch: 98 | Batch: [64/100] | loss: 0.3786
# # Epoch: 98 | Batch: [96/100] | loss: 0.4012
# # Epoch: 99 | Batch: [32/100] | loss: 0.4001
# # Epoch: 99 | Batch: [64/100] | loss: 0.3758
# # Epoch: 99 | Batch: [96/100] | loss: 0.3914
# # Epoch: 100 | Batch: [32/100] | loss: 0.3857
# # Epoch: 100 | Batch: [64/100] | loss: 0.3782
# # Epoch: 100 | Batch: [96/100] | loss: 0.3912

# %% [markdown]
# # 可視化
#
# ---

# %% [markdown]
# 生成されるグラフを数値として評価することは困難なので,可視化することで評価します.
# 何回も生成してみてください．毎回違うグラフが生成されるはずです.

# %%
model.eval()
g = model()

print('ノードの数   :　', g.number_of_nodes())
print('エッジの本数　：　', g.number_of_edges())
nx.draw_networkx(g.to_networkx(), node_color=[[1.0, 0.45, 0.45]])
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/dgl/base.py:45: DGLWarning: Recommend creating graphs by `dgl.graph(data)` instead of `dgl.DGLGraph(data)`.
#   return warnings.warn(message, category=category, stacklevel=1)
# /usr/local/lib/python3.6/dist-packages/dgl/base.py:45: DGLWarning: DGLGraph.has_edge_between is deprecated. Please use DGLGraph.has_edges_between
#   return warnings.warn(message, category=category, stacklevel=1)
# ノードの数   :　 15
# エッジの本数　：　 54
